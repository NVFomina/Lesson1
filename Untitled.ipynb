# %%
triples = [(1, -12, 20), (1, 17, 72), (1, -7, -44), (1, 9, 8), (1, -2, -63)]

for a, b, c in triples:
    discr = b**2 - 4*a*c
    if discr > 0:
        print((-b + discr**.5)/2*a, (-b - discr**.5)/2*a)
    else:
        if discr == 0:
            print(-b/2*a)
        else:
            print('no solution')
# Out:
# 10.0 2.0
# -8.0 -9.0
# 11.0 -4.0
# -1.0 -8.0
# 9.0 -7.0
